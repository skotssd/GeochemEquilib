% %%
% setup environment
% clear data and number format
clear; format short e
% set path to equilibrium solver
txt=pwd; n=length(txt); rootpath=txt;
n=strfind(rootpath,"USERS"); rootpath=txt(1:n-2);
PHREEQCpath=[rootpath,'/runPHREEQC'];
addpath(PHREEQCpath);
JEQUILIBpath=[rootpath,'/JEQUILIB'];
addpath(JEQUILIBpath);
% turn off warnings
warning off
graphics_toolkit ("notebook"); 
%graphics_toolkit ("plotly"); 
%graphics_toolkit("gnuplot")
% delete phreeqcrunfile
%system("rm porttest.txt");
database=['llnl.dat'];

% %% [markdown]
% # Variables
%
% These are the default values I wrote this script with.  The next cell you can change them.
%
% XP=0.1 mol/L.  the initial amount of portlandite. should be a big number.
%
% XC=1e-6 mol/L.  seed crystal amount (if zero then won't ever ppte because multiplication by zero).  1e-6 value from that paper from Australia.
%
% kP=1e-5. just set as an arbitrary value.  need data to help figure out a reasonable value.
%
% kC=1e-4. just set as an arbitrary value. need data to help figure out a  reasonable value.  makes sense to be faster than dissolution?
%
% logPCO2=-3.5
%
% kCO2=8.5e-7.  I picked a value that CO2 would go in slow enough. too fast and it just looks like the CO2 equilbirated model I made before.  (and show as a blue line in the graph below).

% %%
% variables

% amounts
%XP=0.5;  % there was almost 0.03 mol/L maximum Ca conc  at the beginning of the experiment.  (0.0226 mol/L from measured data (Below))
XC=1e-6; % need seed crystal of calcite.  batstone paper used 1e-6

mass=6; %g of cement. that is 15-25% by weight.
massCaOH2=mass*0.20; molport=massCaOH2/74.093
Vol=1; % volume of the bioreactor
XP=molport/Vol;

%equilib constants
KspP=0.00000660693;  % from https://www.aqion.de/site/16 0.00000660693
KspC=3.31131121e-9;  % Ksp for calcite
KspC=4.7e-9;  % Ksp for calcite
KspC=1e-14;
Ksp=3.8e-9;
logPCO2=-3.3;   % PCO2. measured at 468.4 ppm average in the room

% rate constants
kP=8e-1; %port dissoltuion
kC=1e-4; %calciate ppte
kCO2=5e-4; % gas transfer

% length of time to run the simulation
%logtime=0.05:0.05:2.2; timetry=[0 10.^logtime];

timetry=[0.00 0.10 2.00 24.00 48.00 72.00 96.00 144.00];

%pfit=[-0.177862	-3.40754	-3.45603];
%kP=10^pfit(1); kC=10^pfit(2); kCO2=10^pfit(3);
%XP=0.5*XP;
% Out:
% molport = 1.6196e-02

% %%
[Ca,pH,DIC,time]=CO2CaCO3CaOH2kineticmodel(XP,kP,kC,kCO2,timetry);

% %% [markdown]
% # play with the % occuring as CaOH2  if need more Ca that is a way to get it.
%
% just occoured to me.  that CaOH2 should match the CO2 removal.

% %%
% data
%6 g cement small size

data=[...
%Sampling times (H)	pH A	DIC A (mmol/L)	Conductivity A (us/cm)	Ca2+ (mmol/L)	Si (mmol/L)
0.00	5.84	-0.1881	NaN	0.01702	-0.03982
0.10	11.96	0.7954	2419	4.96925	0.08025
2.00	11.99	1.0141	3390	3.80725	0.02971
24.00	11.3	0.7376	990	0.77950	0.22411
48.00	8.73	0.5577	496	1.92998	0.57714
72.00	8.15	1.1859	557	1.90958	1.15143
96.00	8.15	1.1150	554	1.83288	1.07643
144.00	8.13	1.0494	606	1.84188	1.02107
0.00	5.61	-0.2068 NaN		0.00676	-0.04007
0.10	12.04	0.8275	2608	5.04350	0.08868
2.00	12.15	0.6705	3430	6.72050	0.04064
24.00	11.34	2.0533	871	1.99965	0.26911
48.00	8.55	0.7090	494	1.95345	0.69750
72.00	8.12	1.1136	567	1.85363	1.13643
96.00	8.08	1.1206	538	1.81123	1.09679
144.00	8.10	0.9826	597	1.80800	1.04643
0.00	11.84	0.2322	NaN	0.04982	-0.00836
0.10	11.68	0.9485	2304.0	5.06950	0.09996
2.00	11.92	1.0993	5030	8.65500	0.05936
24.00	11.02	1.1953	1443	2.00810	0.31064
48.00	8.39	1.0427	563	2.04983	0.94643
72.00	8.19	1.1912	695	1.93080	1.13143
96.00	8.18	1.0197	701	1.94583	1.08000
144.00	8.13	0.9578	725	1.88958	0.97643
];

sampletime=data(:,1); samplepH=data(:,2); sampleDIC=(data(:,3)*1e-3); conduct=data(:,4); sampleCa=(data(:,5)*1e-3); 
sampleSi=(data(:,6)*1e-3);

% %%
plot(time,pH,'b-','linewidth',2); ylabel('pH'); xlabel('time')
hold on
plot(sampletime,samplepH,'ko','markersize',8,'markerfacecolor','k')
set(gca,'linewidth',2)

yi = interp1 (time, pH, sampletime);
plot(sampletime,yi,'r.')

residual1=samplepH-yi;

% %%
%plot(time(4:length(time)),Ca(4:length(time))); ylabel('[Ca] in solution'); xlabel('time')
plot(time(1:length(time)),1e3*Ca(1:length(time))); ylabel('[Ca] in solution (mM)'); xlabel('time')
hold on
plot(sampletime,sampleCa*1e3,'ko','markersize',8,'markerfacecolor','k')
set(gca,'linewidth',2)

yi = interp1 (time, Ca, sampletime);

plot(sampletime,yi*1e3,'r.')

residual2=sampleCa*1e3-yi*1e3;

% %%
plot(time(1:length(time)),1e3*DIC(1:length(time))); ylabel('DIC in solution (mM)'); xlabel('time')
hold on
plot(sampletime,sampleDIC*1e3,'ko','markersize',8,'markerfacecolor','k')
set(gca,'linewidth',2)

yi = interp1 (time, DIC, sampletime);
plot(sampletime,yi*1e3,'r.')

residual3=sampleDIC*1e3-yi*1e3;

% %%
Z=[residual1 residual2 residual3];
error=det(Z'*Z)
% Out:
% error = 5.4007e+04

% %%
KspC=3.31131121e-9;
ptst=log10([kP kC kCO2 KspC]);
detZtZ=CO2CaCO3CaOH2kineticmodelerror(ptst,XP,timetry,data)
% Out:
% detZtZ = 5.4007e+04

% %%
options = optimset('Display','iter','TolFun',1e-4,'TolX',1e-4);
pbest=fminsearch(@(p) CO2CaCO3CaOH2kineticmodelerror(p,XP,timetry,data),ptst,options)
% Out:
% f(x0) = 5.4007e+04
% Iter.  1,  how = initial  , nf =   5,  f = 5.4007e+04  (0.0%)
% Iter.  2,  how = reflect,   nf =   6,  f = 5.4007e+04  (0.0%)
% Iter.  3,  how = reflect,   nf =   7,  f = 5.4007e+04  (0.0%)
% Iter.  4,  how = reflect,   nf =   8,  f = 5.4007e+04  (0.0%)
% Iter.  5,  how = shrink,    nf =  14,  f = 3.4332e+04  (36.4%)
% Iter.  6,  how = reflect,   nf =  15,  f = 3.4332e+04  (0.0%)
% Iter.  7,  how = contract,  nf =  17,  f = 3.4332e+04  (0.0%)
% Iter.  8,  how = contract,  nf =  19,  f = 3.4332e+04  (0.0%)
% Iter.  9,  how = shrink,    nf =  25,  f = 3.4332e+04  (0.0%)
% Iter. 10,  how = contract,  nf =  27,  f = 3.4332e+04  (0.0%)
% Iter. 11,  how = reflect,   nf =  28,  f = 3.4332e+04  (0.0%)
% Iter. 12,  how = reflect,   nf =  29,  f = 3.4332e+04  (0.0%)
% Iter. 13,  how = shrink,    nf =  35,  f = 3.4332e+04  (0.0%)
% Iter. 14,  how = reflect,   nf =  36,  f = 3.4332e+04  (0.0%)
% Iter. 15,  how = contract,  nf =  38,  f = 3.4332e+04  (0.0%)
% Iter. 16,  how = contract,  nf =  40,  f = 3.4332e+04  (0.0%)
% Iter. 17,  how = contract,  nf =  42,  f = 3.4332e+04  (0.0%)
% Iter. 18,  how = reflect,   nf =  43,  f = 3.4332e+04  (0.0%)
% Iter. 19,  how = contract,  nf =  45,  f = 3.4332e+04  (0.0%)
% Iter. 20,  how = reflect,   nf =  46,  f = 3.4332e+04  (0.0%)
% Iter. 21,  how = expand,    nf =  48,  f = 2.9699e+04  (13.5%)
% Iter. 22,  how = reflect,   nf =  50,  f = 2.2870e+04  (23.0%)
% Iter. 23,  how = contract,  nf =  52,  f = 2.2870e+04  (0.0%)
% Iter. 24,  how = contract,  nf =  54,  f = 2.2870e+04  (0.0%)
% Iter. 25,  how = contract,  nf =  56,  f = 2.2870e+04  (0.0%)
% Iter. 26,  how = reflect,   nf =  57,  f = 2.2870e+04  (0.0%)
% Iter. 27,  how = reflect,   nf =  58,  f = 2.2870e+04  (0.0%)
% Iter. 28,  how = contract,  nf =  60,  f = 2.2515e+04  (1.6%)
% Iter. 29,  how = contract,  nf =  62,  f = 2.1827e+04  (3.1%)
% Iter. 30,  how = contract,  nf =  64,  f = 2.1827e+04  (0.0%)
% Iter. 31,  how = contract,  nf =  66,  f = 2.1766e+04  (0.3%)
% Iter. 32,  how = contract,  nf =  68,  f = 2.1378e+04  (1.8%)
% Iter. 33,  how = contract,  nf =  70,  f = 2.1378e+04  (0.0%)
% Iter. 34,  how = contract,  nf =  72,  f = 2.1378e+04  (0.0%)
% Iter. 35,  how = reflect,   nf =  74,  f = 2.1356e+04  (0.1%)
% Iter. 36,  how = contract,  nf =  76,  f = 2.1356e+04  (0.0%)
% Iter. 37,  how = contract,  nf =  78,  f = 2.1342e+04  (0.1%)
% Iter. 38,  how = contract,  nf =  80,  f = 2.1291e+04  (0.2%)
% Iter. 39,  how = contract,  nf =  82,  f = 2.1291e+04  (0.0%)
% Iter. 40,  how = contract,  nf =  84,  f = 2.1291e+04  (0.0%)
% Iter. 41,  how = contract,  nf =  86,  f = 2.1291e+04  (0.0%)
% Iter. 42,  how = reflect,   nf =  87,  f = 2.1291e+04  (0.0%)
% Iter. 43,  how = contract,  nf =  89,  f = 2.1291e+04  (0.0%)
% Iter. 44,  how = contract,  nf =  91,  f = 2.1291e+04  (0.0%)
% Iter. 45,  how = contract,  nf =  93,  f = 2.1291e+04  (0.0%)
% Iter. 46,  how = contract,  nf =  95,  f = 2.1291e+04  (0.0%)
% Iter. 47,  how = contract,  nf =  97,  f = 2.1269e+04  (0.1%)
% Iter. 48,  how = contract,  nf =  99,  f = 2.1269e+04  (0.0%)
% Iter. 49,  how = shrink,    nf = 105,  f = 2.1269e+04  (0.0%)
% Iter. 50,  how = reflect,   nf = 106,  f = 2.1269e+04  (0.0%)
% Iter. 51,  how = contract,  nf = 108,  f = 2.1269e+04  (0.0%)
% Iter. 52,  how = reflect,   nf = 109,  f = 2.1269e+04  (0.0%)
% Iter. 53,  how = reflect,   nf = 110,  f = 2.1269e+04  (0.0%)
% Iter. 54,  how = shrink,    nf = 116,  f = 2.1264e+04  (0.0%)
% Iter. 55,  how = reflect,   nf = 117,  f = 2.1264e+04  (0.0%)
% Iter. 56,  how = reflect,   nf = 118,  f = 2.1264e+04  (0.0%)
% Iter. 57,  how = shrink,    nf = 124,  f = 2.1264e+04  (0.0%)
% Iter. 58,  how = contract,  nf = 126,  f = 2.1264e+04  (0.0%)
% Iter. 59,  how = reflect,   nf = 128,  f = 2.1255e+04  (0.0%)
% Iter. 60,  how = reflect,   nf = 129,  f = 2.1255e+04  (0.0%)
% Iter. 61,  how = contract,  nf = 131,  f = 2.1255e+04  (0.0%)
% Iter. 62,  how = shrink,    nf = 137,  f = 2.1254e+04  (0.0%)
% Iter. 63,  how = reflect,   nf = 138,  f = 2.1254e+04  (0.0%)
% Iter. 64,  how = shrink,    nf = 144,  f = 2.1254e+04  (0.0%)
% Iter. 65,  how = reflect,   nf = 145,  f = 2.1254e+04  (0.0%)
% Iter. 66,  how = reflect,   nf = 146,  f = 2.1254e+04  (0.0%)
% Iter. 67,  how = shrink,    nf = 152,  f = 2.1254e+04  (0.0%)
% Iter. 68,  how = contract,  nf = 154,  f = 2.1254e+04  (0.0%)
% Iter. 69,  how = shrink,    nf = 160,  f = 2.1254e+04  (0.0%)
% Iter. 70,  how = shrink,    nf = 166,  f = 2.1254e+04  (0.0%)
% Iter. 71,  how = reflect,   nf = 167,  f = 2.1254e+04  (0.0%)
% Iter. 72,  how = contract,  nf = 169,  f = 2.1254e+04  (0.0%)
% Iter. 73,  how = reflect,   nf = 170,  f = 2.1254e+04  (0.0%)
% Iter. 74,  how = contract,  nf = 172,  f = 2.1245e+04  (0.0%)
% Iter. 75,  how = shrink,    nf = 178,  f = 2.1245e+04  (0.0%)
% Iter. 76,  how = shrink,    nf = 184,  f = 2.1245e+04  (0.0%)
% Iter. 77,  how = reflect,   nf = 185,  f = 2.1245e+04  (0.0%)
% Iter. 78,  how = reflect,   nf = 186,  f = 2.1245e+04  (0.0%)
% Iter. 79,  how = reflect,   nf = 187,  f = 2.1245e+04  (0.0%)
% Iter. 80,  how = reflect,   nf = 188,  f = 2.1245e+04  (0.0%)
% Iter. 81,  how = contract,  nf = 190,  f = 2.1241e+04  (0.0%)
% Iter. 82,  how = reflect,   nf = 191,  f = 2.1241e+04  (0.0%)
% Iter. 83,  how = shrink,    nf = 197,  f = 2.1241e+04  (0.0%)
% Iter. 84,  how = reflect,   nf = 198,  f = 2.1241e+04  (0.0%)
% Iter. 85,  how = reflect,   nf = 199,  f = 2.1241e+04  (0.0%)
% Iter. 86,  how = shrink,    nf = 205,  f = 0.0000e+00  (100.0%)
% Iter. 87,  how = reflect,   nf = 206,  f = 0.0000e+00  (0.0%)
% Iter. 88,  how = shrink,    nf = 212,  f = 0.0000e+00  (0.0%)
% Iter. 89,  how = reflect,   nf = 213,  f = 0.0000e+00  (0.0%)
% Iter. 90,  how = reflect,   nf = 214,  f = 0.0000e+00  (0.0%)
% Iter. 91,  how = shrink,    nf = 220,  f = 0.0000e+00  (0.0%)
% Iter. 92,  how = reflect,   nf = 221,  f = 0.0000e+00  (0.0%)
% Iter. 93,  how = shrink,    nf = 227,  f = 0.0000e+00  (0.0%)
% Iter. 94,  how = contract,  nf = 229,  f = 0.0000e+00  (0.0%)
% Iter. 95,  how = shrink,    nf = 235,  f = 0.0000e+00  (0.0%)
% Iter. 96,  how = shrink,    nf = 241,  f = 0.0000e+00  (0.0%)
% Iter. 97,  how = shrink,    nf = 247,  f = 0.0000e+00  (0.0%)
% Iter. 98,  how = shrink,    nf = 253,  f = 0.0000e+00  (0.0%)
% Iter. 99,  how = shrink,    nf = 259,  f = 0.0000e+00  (0.0%)
% Iter. 100,  how = shrink,    nf = 265,  f = 0.0000e+00  (0.0%)
% Iter. 101,  how = shrink,    nf = 271,  f = 0.0000e+00  (0.0%)
% Iter. 102,  how = shrink,    nf = 277,  f = 0.0000e+00  (0.0%)
% Iter. 103,  how = shrink,    nf = 283,  f = 0.0000e+00  (0.0%)
% Iter. 104,  how = shrink,    nf = 289,  f = 0.0000e+00  (0.0%)
% Iter. 105,  how = shrink,    nf = 295,  f = 0.0000e+00  (0.0%)
% Iter. 106,  how = shrink,    nf = 301,  f = 0.0000e+00  (0.0%)
% Iter. 107,  how = shrink,    nf = 307,  f = 0.0000e+00  (0.0%)
% Iter. 108,  how = shrink,    nf = 313,  f = 0.0000e+00  (0.0%)
% Iter. 109,  how = shrink,    nf = 319,  f = 0.0000e+00  (0.0%)
% Iter. 110,  how = shrink,    nf = 325,  f = 0.0000e+00  (0.0%)
% Iter. 111,  how = shrink,    nf = 331,  f = 0.0000e+00  (0.0%)
% Iter. 112,  how = shrink,    nf = 337,  f = 0.0000e+00  (0.0%)
% Iter. 113,  how = shrink,    nf = 343,  f = 0.0000e+00  (0.0%)
% Iter. 114,  how = shrink,    nf = 349,  f = 0.0000e+00  (0.0%)
% Iter. 115,  how = shrink,    nf = 355,  f = 0.0000e+00  (0.0%)
% Iter. 116,  how = shrink,    nf = 361,  f = 0.0000e+00  (0.0%)
% Iter. 117,  how = shrink,    nf = 367,  f = 0.0000e+00  (0.0%)
% Iter. 118,  how = shrink,    nf = 373,  f = 0.0000e+00  (0.0%)
% Iter. 119,  how = shrink,    nf = 379,  f = 0.0000e+00  (0.0%)
% Iter. 120,  how = shrink,    nf = 385,  f = 0.0000e+00  (0.0%)
% Iter. 121,  how = shrink,    nf = 391,  f = 0.0000e+00  (0.0%)
% Iter. 122,  how = shrink,    nf = 397,  f = 0.0000e+00  (0.0%)
% Iter. 123,  how = shrink,    nf = 403,  f = 0.0000e+00  (0.0%)
% Iter. 124,  how = shrink,    nf = 409,  f = 0.0000e+00  (0.0%)
% Iter. 125,  how = shrink,    nf = 415,  f = 0.0000e+00  (0.0%)
% Iter. 126,  how = shrink,    nf = 421,  f = 0.0000e+00  (0.0%)
% Iter. 127,  how = shrink,    nf = 427,  f = 0.0000e+00  (0.0%)
% Iter. 128,  how = shrink,    nf = 433,  f = 0.0000e+00  (0.0%)
% Iter. 129,  how = shrink,    nf = 439,  f = 0.0000e+00  (0.0%)
% Iter. 130,  how = shrink,    nf = 445,  f = 0.0000e+00  (0.0%)
% Iter. 131,  how = shrink,    nf = 451,  f = 0.0000e+00  (0.0%)
% Iter. 132,  how = shrink,    nf = 457,  f = 0.0000e+00  (0.0%)
% Iter. 133,  how = shrink,    nf = 463,  f = 0.0000e+00  (0.0%)
% Iter. 134,  how = shrink,    nf = 469,  f = 0.0000e+00  (0.0%)
% Iter. 135,  how = reflect,   nf = 470,  f = 0.0000e+00  (0.0%)
% ERROR: during execute_request
% exit exception
