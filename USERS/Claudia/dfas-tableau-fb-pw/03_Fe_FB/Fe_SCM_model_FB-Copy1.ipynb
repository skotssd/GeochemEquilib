% %%
clc; clear; close all;

warning off
% graphics_toolkit("plotly")

graphics_toolkit("gnuplot");
set(0, "defaultlinelinewidth", 2); % Líneas más gruesas
set(0, "defaultaxesfontsize", 12); % Letra más grande

% -- Simulation Inputs --
pHvals = 2:0.2:12;  % pH range for the simulation
FeT    = 1e-5;      % Total Iron concentration (mol/L)
PT     = 1e-5;      % Total Phosphate concentration (mol/L)
peINT  = 5.75;      % pe0 value (redox condition)
HFOsi  = 0.005;     % Moles of strong adsorption sites per mole of Fe(OH)3(s)
HFOwi  = 0.2;       % Moles of weak adsorption sites per mole of Fe(OH)3(s)

% %%
adaptive_Fe_redox_adsorption_FB_solver3(pHvals, FeT, PT, peINT, HFOsi, HFOwi);
% Out:
% Reducing conditions detected. Using guess for vivianite.
% Starting simulation...
% Simulation completed.
% Total execution time: 0.74 seconds
%
%
%            |------------Solids, dissolved Fe(III), and HFO-P----------------|
%           +|           +            +            +            +            +|
%           +|           +            +            + +----------------------++|
%     1e-05 &|+&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&|***F***F*FFF*Fs      +|&|
%           &|           &            &            & |###D###FePO4(s)       |&|
%           &|           &            &            & |$$$H$$$Fe3+PO4)2(s)   |&|
%     8e-06 &|+&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&|%%%H%%%Fe   (aq)*F   +|&|
%           &|           &            &            & +@@@B@@@HFO-P (PO4 ads)+&|
%           &|           &            &            &        *   &       *    &|
%     6e-06 &|+&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&*&&&&&&&&&&&&*&+-&|
%           &|           &            &            &        *   &        F   &|
%           &|           &            &            &        *   &        *   &|
%     4e-06 &|+&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&*&&&&&&&&&&&&*&+-&|
%           &|           &            &            &       *    &         *  &|
%           &|           &            &            &       *    &         *  &|
%     2e-06 &|+&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&$HH&B@BBB@BBB@B&&F+-&|
%           &|           &            &            &   HH  $B   &       BB * &|
%           +|----------------------------------------------------------------|
%         0 BB@BBB@BBBB@BBB@BBB@BBBB@BBB@BBB@BBBB@BBB@BBB@BBHH%HHH%HHH%HHHH@BB
%           2            4            6            8           10           12
%                                          pH
%
%
%
%       -12  |---------------------Final Mass Balance-------------------------|
%     10    +|+$$$$$$$$$$+$$$$$$$$$$$$+$$$$$$$$$$$$+$$$$$$$$$$$$+$$$$$$$$$$+-+|
%       -13 +|           +            +         D  +        D +-------------F+|
%     10    $|+$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$##DD$$$$$$$$#$|***F***Err Fe*F|
%       -14 $|           $            $         #  #        ##+###D###Err P-*$|
%     10    D|+$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$#$$#$$$$$$$$##$$$$$$$$$$$$$+*$|
%       -15 #|           $            $         #  #        #D  $          * $|
%     10    #|+$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$#*F#$$$$$$$$##$$$$$$$$$$$$$*-$|
%           #|           $            $    D    #  #        ##  $          * $|
%           #|           $            $    ##  #*  *#      #  # $          * $|
%           $|           $            $    # D #*  $#      #  # $          *D$|
%           $|           $            $    #  ##*  $#      #  # $          *#$|
%           F|           $            $   #   D#   $#      #  # $         *# #|
%           $|           $   F        $   #F   #   $#*     #   #$         *# D|
%           $|*FFF*FFFF*FFF*F F*FDFF*FFF  # *F D   $D*     #   #$         #  $|
%           $|#DDD#DD    $ #DDD#D DD#DD #DD   F*   $ #FFD#DD   DD    D  DFD  $|
%           $|       DD#DDD           $D       *   $  D #*FFF   $D#D ##DFD   $|
%           +|----------------------------------------------------------------|
%           +            +            +            +          *FFF*F         +
%           2            4            6            8           10           12
%                                          pH
% Execution exception: set: invalid value for radio property "location"
% error: called from
%     __gnuplot_legend__ at line 679 column 14
%     legend at line 199 column 39
%     adaptive_Fe_redox_adsorption_FB_solver3 at line 276 column 10
%    |
%    |       |------------Adsorption Site Errors and Totals--------------|
%   2|5e-13 $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$+-+|e-06
%    |      $|          $           $           $          KKKK         $|
%    |      $|          $           $           $         K $  #KK      $|
%    |2e-13 $|+         $           $           $        #  $     #     $|
%    |      $|          $           $           $       D#  $     K     $|
%    |      $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$K$$$$$$$$$$#$$+-+|.5e-06
%   1|5e-13 $|+         $           $           $       #   $      K    $|
%    |      $|          $           $           $       ##  $      #    $|
%    |      $|          $           $           $       ##  $       #   $|
%    |1e-13 $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$#$$$$$$$$$$$K$+-+|e-06
%    |      $|          $           $           $       ##  $       # Tot|l sites
%    |      $|          $           $           $      ###  $        #  $|
%    |      $|          $           $           $      ###  $        #  $|
%    |5e-14 $|+         $           $           $      #  # $        #  $|
%    |      $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$#$$$$$$$$$$$$$$#-+|e-07
%    |      $|          $           $           $      #  # $         K $|
%    |    0 $|D#DDDDD#DD$DD#DDDDD#DD$DD#DDDDD#DD$DD#DDD#F*DD$DD#DDDDD##D$|
%    |      $|          $           $           $      #    $          #$|
%    |--------------------------------------------------------------------------
%    -5e-14 KKK#KKKKK#KKKKK#KKKKK#KKKKK#KKKKK#KKKKK#KKKKH*HHHHH*HHHHH*HKK0
%           2           4           6           8          10          12
%                                        pH
% ERROR: received unknown message
% Message type: usage_request
